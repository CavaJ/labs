# %%
import collections
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

import math 
import os 
import random 
import zipfile 
from six.moves import urllib 
from six.moves import xrange  # pylint: disable=redefined-builtin
from sklearn.manifold import TSNE

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# ('Found and verified', 'text8.zip')

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# ('Data size', 17005207)

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# ('Most common words (+UNK)', [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)])
# ('Sample data', [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156], ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against'])

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# (3084, 'originated', '->', 12, 'as')
# (3084, 'originated', '->', 5239, 'anarchism')
# (12, 'as', '->', 6, 'a')
# (12, 'as', '->', 3084, 'originated')
# (6, 'a', '->', 12, 'as')
# (6, 'a', '->', 195, 'term')
# (195, 'term', '->', 2, 'of')
# (195, 'term', '->', 6, 'a')

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.initialize_all_variables()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# ('Average loss at step ', 0, ': ', 288.23977661132812)
# Nearest to as: basil, irrelevant, hamza, lcs, canarian, attendants, rotates, harshly,
# Nearest to than: grabs, syringe, cracow, shatila, confounding, matic, oi, ohio,
# Nearest to however: moisture, chagrin, cuba, exchequer, gyroscopic, abiogenesis, configuration, shall,
# Nearest to no: milius, reptiles, pynchon, formalisms, hilltop, shortest, arrhythmias, monopoly,
# Nearest to this: toured, gyeongsang, challenging, attraction, expunged, decarlo, stalk, renegades,
# Nearest to may: cauldron, windmill, executed, compartment, unclaimed, outrun, forwarded, ensues,
# Nearest to over: manar, digests, tempus, laval, totaled, cleaves, tf, uncomfortable,
# Nearest to are: waterbury, lest, elkins, fujimori, nietzsche, industrialist, elmer, unimpeded,
# Nearest to who: rarities, chests, elects, verify, dordrecht, bags, adb, xanadu,
# Nearest to his: distillery, hungarians, isoroku, montoya, pines, albatrosses, hammett, plastics,
# Nearest to such: advert, anaesthesia, antarctic, sancti, scavenging, ingeborg, gosford, titration,
# Nearest to if: swordfish, lengthening, uruguay, challenger, conte, arcades, drastically, cilia,
# Nearest to been: anthropomorphized, aberrant, sponsored, orlando, bison, docklands, welcome, australis,
# Nearest to the: correlatives, zygote, serenity, sandstorms, llewellyn, uppercase, courteous, multiplan,
# Nearest to has: limousine, inquirer, legal, join, sternberg, peta, wavefunctions, horned,
# Nearest to a: playboy, guadeloupe, reduction, mokhehle, highways, aur, reconstructed, wassily,
# ('Average loss at step ', 2000, ': ', 113.72089775562286)
# ('Average loss at step ', 4000, ': ', 53.007565256118774)
# ('Average loss at step ', 6000, ': ', 33.075641038656237)
# ('Average loss at step ', 8000, ': ', 23.867881739616394)
# ('Average loss at step ', 10000, ': ', 18.019063786268234)
# Nearest to as: and, phi, alpina, argentina, is, in, basil, on,
# Nearest to than: ohio, buddhism, aol, lectures, jackson, grabs, cannabis, altenberg,
# Nearest to however: shall, austin, moisture, prussian, alpina, cuba, gb, special,
# Nearest to no: milius, sides, shortest, analog, sky, independent, austin, accept,
# Nearest to this: the, hogeschool, austin, tubing, mentioned, a, ancestor, test,
# Nearest to may: can, religion, oath, has, executed, extends, will, flame,
# Nearest to over: spots, definitions, ignosticism, directed, arguing, literature, vs, mind,
# Nearest to are: is, spectral, were, dogmatic, empty, and, insulation, wisconsin,
# Nearest to who: and, retired, construct, jonas, expect, truly, austin, bequest,
# Nearest to his: the, a, austria, wheel, knighted, and, UNK, absurd,
# Nearest to such: var, antarctic, demographics, nextstep, alpina, midi, austin, authoritarian,
# Nearest to if: sanjaks, represents, victoriae, uruguay, creating, route, austin, gb,
# Nearest to been: be, gang, sponsored, fish, riemann, we, kennedy, armor,
# Nearest to the: a, his, UNK, and, austin, austria, its, their,
# Nearest to has: is, buttons, legal, join, may, have, was, for,
# Nearest to a: the, and, mercury, his, advantages, ski, austin, grandparents,
# ('Average loss at step ', 12000, ': ', 13.886884005188943)
# ('Average loss at step ', 14000, ': ', 11.840435679674149)
# ('Average loss at step ', 16000, ': ', 9.5679419665336614)
# ('Average loss at step ', 18000, ': ', 8.6901744445562361)
# ('Average loss at step ', 20000, ': ', 7.732801080584526)
# Nearest to as: and, is, was, in, by, for, agouti, phi,
# Nearest to than: or, lectures, ohio, buddhism, confounded, grabs, cannabis, putty,
# Nearest to however: shall, and, so, moisture, prussian, alpina, agouti, configuration,
# Nearest to no: and, dasyprocta, antoninus, analog, reptiles, he, still, independent,
# Nearest to this: the, it, dasyprocta, a, deposits, his, guided, brigham,
# Nearest to may: can, will, oath, has, extends, distorted, six, religion,
# Nearest to over: and, latinus, spots, arguing, through, elites, seven, definitions,
# Nearest to are: were, is, was, ell, zero, dogmatic, dasyprocta, spectral,
# Nearest to who: and, belladonna, it, he, construct, ilya, retired, truly,
# Nearest to his: the, a, austria, their, its, this, s, wheel,
# Nearest to such: sancti, nextstep, demographics, var, antarctic, facilitated, locally, being,
# Nearest to if: sanjaks, represents, agouti, route, cordial, uruguay, creating, amino,
# Nearest to been: be, was, we, as, gang, have, by, calculates,
# Nearest to the: its, his, a, dasyprocta, their, and, an, one,
# Nearest to has: is, was, have, had, buttons, legal, join, may,
# Nearest to a: the, dasyprocta, advantages, imran, their, agouti, his, this,
# ('Average loss at step ', 22000, ': ', 7.1023930258750916)
# ('Average loss at step ', 24000, ': ', 6.9827466551065447)
# ('Average loss at step ', 26000, ': ', 6.7169820896387105)
# ('Average loss at step ', 28000, ': ', 6.1668487408161159)
# ('Average loss at step ', 30000, ': ', 6.176309322118759)
# Nearest to as: is, by, was, and, in, agouti, phi, alpina,
# Nearest to than: or, lectures, cannabis, confounded, and, buddhism, ohio, grabs,
# Nearest to however: so, shall, agouti, special, alpina, moisture, configuration, and,
# Nearest to no: it, a, who, he, still, this, dasyprocta, pie,
# Nearest to this: it, the, abitibi, which, dasyprocta, a, there, deposits,
# Nearest to may: can, will, could, buffer, rodin, nine, would, extends,
# Nearest to over: through, latinus, and, spots, loran, spectre, first, arguing,
# Nearest to are: were, is, have, was, dasyprocta, dogmatic, spectral, ell,
# Nearest to who: he, and, it, belladonna, no, abet, construct, been,
# Nearest to his: the, their, s, her, its, abitibi, a, investiture,
# Nearest to such: sancti, well, nextstep, midi, demographics, known, facilitated, thinkpad,
# Nearest to if: when, represents, is, bronte, cordial, agouti, sanjaks, although,
# Nearest to been: be, was, by, we, have, who, armor, gang,
# Nearest to the: their, its, his, abitibi, a, dasyprocta, this, austin,
# Nearest to has: is, was, had, have, buttons, join, legal, petroleum,
# Nearest to a: abitibi, the, advantages, dasyprocta, pike, imran, abakan, this,
# ('Average loss at step ', 32000, ': ', 5.841335013151169)
# ('Average loss at step ', 34000, ': ', 5.8405527998208999)
# ('Average loss at step ', 36000, ': ', 5.6942042449712753)
# ('Average loss at step ', 38000, ': ', 5.3030205897092824)
# ('Average loss at step ', 40000, ': ', 5.4334150465726854)
# Nearest to as: guderian, agouti, asterism, primigenius, is, in, phi, abet,
# Nearest to than: or, lectures, and, grabs, confounded, cannabis, buddhism, putty,
# Nearest to however: shall, so, but, and, agouti, special, configuration, moisture,
# Nearest to no: a, it, still, who, this, that, and, dasyprocta,
# Nearest to this: it, the, which, abitibi, dasyprocta, a, that, guided,
# Nearest to may: can, will, could, would, should, buffer, nine, rodin,
# Nearest to over: through, spectre, latinus, first, spots, loran, when, seven,
# Nearest to are: were, is, have, was, vma, wisconsin, dasyprocta, spectral,
# Nearest to who: he, and, it, which, belladonna, no, they, abet,
# Nearest to his: their, the, its, her, s, abitibi, drysdale, distillery,
# Nearest to such: sancti, well, known, nextstep, demographics, midi, habit, erupts,
# Nearest to if: when, although, agouti, represents, bronte, sanjaks, cordial, trinomial,
# Nearest to been: be, was, by, have, armor, anthropomorphized, calculates, who,
# Nearest to the: a, its, their, abitibi, his, dasyprocta, this, austin,
# Nearest to has: had, was, have, is, buttons, legal, eight, lowry,
# Nearest to a: the, abitibi, dasyprocta, another, guitars, aba, imran, this,
# ('Average loss at step ', 42000, ': ', 5.3296833069324494)
# ('Average loss at step ', 44000, ': ', 5.3597890273332593)
# ('Average loss at step ', 46000, ': ', 5.2634685928821563)
# ('Average loss at step ', 48000, ': ', 5.0284997729063035)
# ('Average loss at step ', 50000, ': ', 5.1726235127449032)
# Nearest to as: agouti, revolt, primigenius, guderian, in, abet, phi, is,
# Nearest to than: or, lectures, grabs, confounded, cannabis, putty, but, and,
# Nearest to however: but, and, shall, so, agouti, special, configuration, when,
# Nearest to no: a, still, it, this, thibetanus, who, dasyprocta, antoninus,
# Nearest to this: it, which, the, abitibi, dasyprocta, that, another, there,
# Nearest to may: can, will, could, would, should, nine, might, buffer,
# Nearest to over: through, first, spectre, spots, latinus, loran, arguing, on,
# Nearest to are: were, is, have, was, spectral, be, vma, bronte,
# Nearest to who: he, and, which, they, belladonna, it, also, no,
# Nearest to his: their, its, the, her, s, abitibi, thibetanus, investiture,
# Nearest to such: well, sancti, known, habit, erupts, nextstep, midi, these,
# Nearest to if: when, although, agouti, represents, that, cordial, bronte, sanjaks,
# Nearest to been: be, was, by, armor, anthropomorphized, have, pipe, were,
# Nearest to the: their, its, dasyprocta, abitibi, a, his, this, austin,
# Nearest to has: had, was, have, is, limousine, eight, buttons, were,
# Nearest to a: abitibi, the, another, balderus, guitars, thibetanus, pike, advantages,
# ('Average loss at step ', 52000, ': ', 5.1639384784698485)
# ('Average loss at step ', 54000, ': ', 5.1274419661760327)
# ('Average loss at step ', 56000, ': ', 5.0647227741479872)
# ('Average loss at step ', 58000, ': ', 5.1119718358516693)
# ('Average loss at step ', 60000, ': ', 4.9700638670325281)
# Nearest to as: tamarin, whirlpool, callithrix, agouti, microcebus, guderian, austin, primigenius,
# Nearest to than: or, lectures, and, grabs, confounded, but, cannabis, putty,
# Nearest to however: but, tamarin, agouti, shall, so, when, and, then,
# Nearest to no: a, still, it, thibetanus, this, dasyprocta, pie, and,
# Nearest to this: it, which, that, the, dasyprocta, there, abitibi, another,
# Nearest to may: can, will, could, would, should, might, buffer, rodin,
# Nearest to over: through, tamarin, first, spectre, callithrix, on, spots, arguing,
# Nearest to are: were, is, have, be, vma, tamarin, spectral, bronte,
# Nearest to who: he, which, they, it, belladonna, that, also, not,
# Nearest to his: their, her, its, the, s, abitibi, investiture, cebus,
# Nearest to such: well, sancti, these, habit, known, many, certain, erupts,
# Nearest to if: when, although, tamarin, is, cordial, represents, where, that,
# Nearest to been: be, was, by, were, armor, anthropomorphized, had, nine,
# Nearest to the: its, their, tamarin, abitibi, microcebus, a, dasyprocta, his,
# Nearest to has: had, was, have, is, limousine, gained, callithrix, tamarin,
# Nearest to a: the, abitibi, another, michelob, dasyprocta, callithrix, guitars, tamarin,
# ('Average loss at step ', 62000, ': ', 4.7788269153833394)
# ('Average loss at step ', 64000, ': ', 4.8045102977752689)
# ('Average loss at step ', 66000, ': ', 4.972397524476051)
# ('Average loss at step ', 68000, ': ', 4.9104451566934584)
# ('Average loss at step ', 70000, ': ', 4.7770166647434236)
# Nearest to as: tamarin, callithrix, whirlpool, primigenius, guderian, agouti, microcebus, revolt,
# Nearest to than: or, lectures, and, confounded, but, grabs, ssbn, cannabis,
# Nearest to however: but, tamarin, when, agouti, shall, which, while, austin,
# Nearest to no: a, still, it, this, thibetanus, pie, or, harriet,
# Nearest to this: it, which, the, that, another, abitibi, dasyprocta, microcebus,
# Nearest to may: can, will, could, would, should, might, honduran, pulau,
# Nearest to over: through, tamarin, spectre, callithrix, catalysis, when, legal, loran,
# Nearest to are: were, is, have, be, upanija, bronte, tamarin, vma,
# Nearest to who: he, which, they, belladonna, it, that, and, usually,
# Nearest to his: their, her, its, the, abitibi, s, investiture, pines,
# Nearest to such: well, these, known, many, some, habit, certain, other,
# Nearest to if: when, although, tamarin, compost, cordial, is, where, represents,
# Nearest to been: be, was, were, by, armor, had, anthropomorphized, pipe,
# Nearest to the: its, their, tamarin, this, dasyprocta, abitibi, microcebus, a,
# Nearest to has: had, have, was, is, tamarin, callithrix, limousine, gained,
# Nearest to a: abitibi, the, another, pike, tamarin, msg, imran, callithrix,
# ('Average loss at step ', 72000, ': ', 4.7908321659564974)
# ('Average loss at step ', 74000, ': ', 4.7676656162142752)
# ('Average loss at step ', 76000, ': ', 4.8844704730510715)
# ('Average loss at step ', 78000, ': ', 4.8075266581773759)
# ('Average loss at step ', 80000, ': ', 4.8127956146001818)
# Nearest to as: tamarin, revolt, callithrix, became, infect, microcebus, whirlpool, agouti,
# Nearest to than: or, lectures, but, confounded, and, grabs, ssbn, while,
# Nearest to however: but, tamarin, when, agouti, although, while, austin, then,
# Nearest to no: a, still, it, thibetanus, any, dasyprocta, antoninus, iit,
# Nearest to this: it, which, iit, the, that, another, abitibi, dasyprocta,
# Nearest to may: can, will, could, would, should, might, must, honduran,
# Nearest to over: through, tamarin, spectre, when, callithrix, on, catalysis, loran,
# Nearest to are: were, is, have, be, upanija, while, tamarin, bronte,
# Nearest to who: he, which, they, it, and, belladonna, never, incestuous,
# Nearest to his: their, her, its, the, s, abitibi, investiture, jinn,
# Nearest to such: well, these, many, known, certain, habit, pontificia, some,
# Nearest to if: when, although, tamarin, where, disturbed, cordial, before, though,
# Nearest to been: be, was, were, by, become, had, armor, nine,
# Nearest to the: its, their, tamarin, abitibi, dasyprocta, microcebus, his, cebus,
# Nearest to has: had, have, was, is, cegep, but, gained, tamarin,
# Nearest to a: the, abitibi, another, no, cegep, balderus, ige, pike,
# ('Average loss at step ', 82000, ': ', 4.8118763676881793)
# ('Average loss at step ', 84000, ': ', 4.7751395889520643)
# ('Average loss at step ', 86000, ': ', 4.7750073729753497)
# ('Average loss at step ', 88000, ': ', 4.6858195184469222)
# ('Average loss at step ', 90000, ': ', 4.779146430134773)
# Nearest to as: whirlpool, tamarin, agouti, callithrix, revolt, microcebus, guderian, primigenius,
# Nearest to than: or, lectures, confounded, but, grabs, ssbn, putty, while,
# Nearest to however: but, tamarin, when, agouti, although, while, which, and,
# Nearest to no: a, still, it, any, dasyprocta, thibetanus, there, iit,
# Nearest to this: it, which, iit, the, another, that, dasyprocta, abitibi,
# Nearest to may: can, could, will, would, should, might, must, honduran,
# Nearest to over: through, spectre, tamarin, callithrix, when, steelers, militare, catalysis,
# Nearest to are: were, have, is, be, while, tamarin, upanija, infect,
# Nearest to who: he, they, which, never, incestuous, and, it, belladonna,
# Nearest to his: their, her, its, the, s, abitibi, investiture, informational,
# Nearest to such: well, these, known, certain, many, some, other, habit,
# Nearest to if: when, although, where, tamarin, though, is, agouti, disturbed,
# Nearest to been: be, was, were, become, by, had, armor, pipe,
# Nearest to the: its, their, tamarin, dasyprocta, abitibi, microcebus, cegep, this,
# Nearest to has: had, have, was, is, cegep, tamarin, although, having,
# Nearest to a: abitibi, the, another, pike, cegep, no, any, rial,
# ('Average loss at step ', 92000, ': ', 4.7045230696201328)
# ('Average loss at step ', 94000, ': ', 4.6155414705276492)
# ('Average loss at step ', 96000, ': ', 4.7353039612770083)
# ('Average loss at step ', 98000, ': ', 4.6165121049880984)
# ('Average loss at step ', 100000, ': ', 4.6660660425424574)
# Nearest to as: tamarin, whirlpool, agouti, callithrix, revolt, guderian, microcebus, infect,
# Nearest to than: or, lectures, confounded, but, and, grabs, while, much,
# Nearest to however: but, and, tamarin, although, when, while, agouti, that,
# Nearest to no: a, still, any, it, evaluated, thibetanus, antoninus, iit,
# Nearest to this: it, which, iit, that, the, another, microcebus, there,
# Nearest to may: can, could, will, would, should, might, must, cannot,
# Nearest to over: through, tamarin, spectre, when, callithrix, three, militare, steelers,
# Nearest to are: were, have, is, be, while, tamarin, include, upanija,
# Nearest to who: he, they, which, never, and, incestuous, it, also,
# Nearest to his: their, her, its, the, s, abitibi, informational, investiture,
# Nearest to such: well, these, many, known, certain, some, other, habit,
# Nearest to if: when, although, where, though, is, disturbed, tamarin, represents,
# Nearest to been: be, was, become, were, by, herein, had, armor,
# Nearest to the: its, their, microcebus, tamarin, abitibi, dasyprocta, his, cegep,
# Nearest to has: had, have, was, is, cegep, having, tamarin, callithrix,
# Nearest to a: abitibi, the, another, any, cegep, pike, balderus, dasyprocta,

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
